# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# import keras
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
    # for filename in filenames:
        # print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train_data_dir = "/kaggle/input/fer2013/train"
validation_data_dir = "/kaggle/input/fer2013/test"

# %%
IMG_HEIGHT=48 
IMG_WIDTH = 48
batch_size=32

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Flatten
from tensorflow.keras.layers import Conv2D,MaxPooling2D

# %%
train_datagen = ImageDataGenerator(
					rescale=1./255,
					rotation_range=30,
					shear_range=0.3,
					zoom_range=0.3,
					horizontal_flip=True,
					fill_mode='nearest')

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
					train_data_dir,
					color_mode='grayscale',
					target_size=(IMG_HEIGHT, IMG_WIDTH),
					batch_size=batch_size,
					class_mode='categorical',
					shuffle=True)
# Out:
# Found 28709 images belonging to 7 classes.

# %%
validation_generator = validation_datagen.flow_from_directory(
							validation_data_dir,
							color_mode='grayscale',
							target_size=(IMG_HEIGHT, IMG_WIDTH),
							batch_size=batch_size,
							class_mode='categorical',
							shuffle=True)
# Out:
# Found 7178 images belonging to 7 classes.

# %%
#Verify our generator by plotting a few faces and printing corresponding labels
class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']

img, label = train_generator.__next__()

# %%
import random

i=random.randint(0, (img.shape[0])-1)
image = img[i]
labl = class_labels[label[i].argmax()]
plt.imshow(image[:,:,0], cmap='gray')
plt.title(labl)
plt.show()

# %%
# Create the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(48,48,1)))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Conv2D(256, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.1))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(7, activation='softmax'))

model.compile(optimizer = 'adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 46, 46, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 44, 44, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 20, 20, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 10, 10, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 10, 10, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 512)                 │       2,097,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,489,095 (9.50 MB)
#  Trainable params: 2,489,095 (9.50 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
train_path = "/kaggle/input/fer2013/train"
test_path = "/kaggle/input/fer2013/test"

# %%
num_train_imgs = 0
for root, dirs, files in os.walk(train_path):
    num_train_imgs += len(files)
    
num_test_imgs = 0
for root, dirs, files in os.walk(test_path):
    num_test_imgs += len(files)

# %%
num_train_imgs, num_test_imgs
# Out:
# (28709, 7178)

# %%
epochs=100

history=model.fit(train_generator,
                steps_per_epoch=num_train_imgs//batch_size,
                epochs=epochs,
                validation_data=validation_generator,
                validation_steps=num_test_imgs//batch_size)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 239s 255ms/step - accuracy: 0.2540 - loss: 1.8022 - val_accuracy: 0.3419 - val_loss: 1.6575
# Epoch 2/100
#   1/897 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.5312 - loss: 1.6723
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 1s 941us/step - accuracy: 0.5312 - loss: 1.6723 - val_accuracy: 0.1000 - val_loss: 1.9023
# Epoch 3/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.3237 - loss: 1.6890 - val_accuracy: 0.4000 - val_loss: 1.5362
# Epoch 4/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.3750 - loss: 1.6512 - val_accuracy: 0.3000 - val_loss: 1.4618
# Epoch 5/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - accuracy: 0.3846 - loss: 1.5672 - val_accuracy: 0.4708 - val_loss: 1.3811
# Epoch 6/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.4688 - loss: 1.3698 - val_accuracy: 0.6000 - val_loss: 1.2678
# Epoch 7/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.4314 - loss: 1.4758 - val_accuracy: 0.4972 - val_loss: 1.3101
# Epoch 8/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.6875 - loss: 1.1883 - val_accuracy: 0.8000 - val_loss: 0.9094
# Epoch 9/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 69s 77ms/step - accuracy: 0.4571 - loss: 1.4185 - val_accuracy: 0.5179 - val_loss: 1.2643
# Epoch 10/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.3750 - loss: 1.7757 - val_accuracy: 0.7000 - val_loss: 0.9024
# Epoch 11/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 68s 75ms/step - accuracy: 0.4741 - loss: 1.3651 - val_accuracy: 0.5325 - val_loss: 1.2261
# Epoch 12/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.5000 - loss: 1.4098 - val_accuracy: 0.7000 - val_loss: 0.8426
# Epoch 13/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 69s 76ms/step - accuracy: 0.4822 - loss: 1.3437 - val_accuracy: 0.5409 - val_loss: 1.1919
# Epoch 14/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.4688 - loss: 1.1465 - val_accuracy: 0.3000 - val_loss: 1.4914
# Epoch 15/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5033 - loss: 1.3058 - val_accuracy: 0.5539 - val_loss: 1.1759
# Epoch 16/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 17us/step - accuracy: 0.5625 - loss: 1.3201 - val_accuracy: 0.7000 - val_loss: 0.8154
# Epoch 17/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5096 - loss: 1.2919 - val_accuracy: 0.5243 - val_loss: 1.2498
# Epoch 18/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.4062 - loss: 1.2878 - val_accuracy: 0.6000 - val_loss: 1.0287
# Epoch 19/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5056 - loss: 1.2836 - val_accuracy: 0.5561 - val_loss: 1.1712
# Epoch 20/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.5000 - loss: 1.3831 - val_accuracy: 0.7000 - val_loss: 1.1085
# Epoch 21/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5161 - loss: 1.2745 - val_accuracy: 0.5621 - val_loss: 1.1396
# Epoch 22/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.4375 - loss: 1.3981 - val_accuracy: 0.4000 - val_loss: 1.7877
# Epoch 23/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - accuracy: 0.5227 - loss: 1.2535 - val_accuracy: 0.5650 - val_loss: 1.1456
# Epoch 24/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.5312 - loss: 1.2570 - val_accuracy: 0.7000 - val_loss: 1.0526
# Epoch 25/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 64s 71ms/step - accuracy: 0.5304 - loss: 1.2339 - val_accuracy: 0.5700 - val_loss: 1.1339
# Epoch 26/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.5312 - loss: 1.3956 - val_accuracy: 0.8000 - val_loss: 0.7624
# Epoch 27/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5335 - loss: 1.2219 - val_accuracy: 0.5762 - val_loss: 1.1269
# Epoch 28/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.5000 - loss: 1.2045 - val_accuracy: 0.6000 - val_loss: 1.2087
# Epoch 29/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - accuracy: 0.5373 - loss: 1.2165 - val_accuracy: 0.5804 - val_loss: 1.1116
# Epoch 30/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.5938 - loss: 0.9694 - val_accuracy: 0.5000 - val_loss: 0.8990
# Epoch 31/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5459 - loss: 1.2021 - val_accuracy: 0.5699 - val_loss: 1.1408
# Epoch 32/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.6875 - loss: 0.8591 - val_accuracy: 0.5000 - val_loss: 1.2985
# Epoch 33/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5398 - loss: 1.2049 - val_accuracy: 0.5818 - val_loss: 1.0960
# Epoch 34/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 18us/step - accuracy: 0.6250 - loss: 1.2293 - val_accuracy: 1.0000 - val_loss: 0.3835
# Epoch 35/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5464 - loss: 1.1917 - val_accuracy: 0.5845 - val_loss: 1.1045
# Epoch 36/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6562 - loss: 1.0252 - val_accuracy: 0.4000 - val_loss: 1.7138
# Epoch 37/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 64s 71ms/step - accuracy: 0.5530 - loss: 1.1839 - val_accuracy: 0.5884 - val_loss: 1.1040
# Epoch 38/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6250 - loss: 0.9747 - val_accuracy: 0.4000 - val_loss: 1.3165
# Epoch 39/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5525 - loss: 1.1832 - val_accuracy: 0.5871 - val_loss: 1.1050
# Epoch 40/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.5938 - loss: 1.1280 - val_accuracy: 0.3000 - val_loss: 1.6563
# Epoch 41/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5454 - loss: 1.1832 - val_accuracy: 0.5864 - val_loss: 1.1063
# Epoch 42/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.5625 - loss: 1.3890 - val_accuracy: 0.5000 - val_loss: 1.0682
# Epoch 43/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 63s 70ms/step - accuracy: 0.5577 - loss: 1.1675 - val_accuracy: 0.5944 - val_loss: 1.0794
# Epoch 44/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.4375 - loss: 1.4126 - val_accuracy: 0.7000 - val_loss: 0.7200
# Epoch 45/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 64s 71ms/step - accuracy: 0.5533 - loss: 1.1670 - val_accuracy: 0.5914 - val_loss: 1.0896
# Epoch 46/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.4688 - loss: 1.3385 - val_accuracy: 0.5000 - val_loss: 1.4550
# Epoch 47/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - accuracy: 0.5505 - loss: 1.1739 - val_accuracy: 0.5925 - val_loss: 1.0763
# Epoch 48/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.6250 - loss: 1.1205 - val_accuracy: 0.4000 - val_loss: 1.3889
# Epoch 49/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 68s 75ms/step - accuracy: 0.5627 - loss: 1.1539 - val_accuracy: 0.5981 - val_loss: 1.0709
# Epoch 50/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.4688 - loss: 1.4974 - val_accuracy: 0.4000 - val_loss: 1.2542
# Epoch 51/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - accuracy: 0.5591 - loss: 1.1552 - val_accuracy: 0.5851 - val_loss: 1.0819
# Epoch 52/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6250 - loss: 0.9105 - val_accuracy: 0.6000 - val_loss: 1.1814
# Epoch 53/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - accuracy: 0.5716 - loss: 1.1421 - val_accuracy: 0.5862 - val_loss: 1.0827
# Epoch 54/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.5000 - loss: 1.2280 - val_accuracy: 0.8000 - val_loss: 0.6526
# Epoch 55/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 74ms/step - accuracy: 0.5658 - loss: 1.1441 - val_accuracy: 0.5992 - val_loss: 1.0582
# Epoch 56/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.5625 - loss: 1.1495 - val_accuracy: 0.5000 - val_loss: 1.1486
# Epoch 57/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 68s 75ms/step - accuracy: 0.5644 - loss: 1.1378 - val_accuracy: 0.5907 - val_loss: 1.0828
# Epoch 58/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6562 - loss: 0.9408 - val_accuracy: 0.9000 - val_loss: 0.5901
# Epoch 59/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5721 - loss: 1.1355 - val_accuracy: 0.6024 - val_loss: 1.0603
# Epoch 60/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6562 - loss: 0.9366 - val_accuracy: 0.7000 - val_loss: 1.0830
# Epoch 61/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5706 - loss: 1.1342 - val_accuracy: 0.5961 - val_loss: 1.0695
# Epoch 62/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.5938 - loss: 1.1422 - val_accuracy: 0.5000 - val_loss: 1.3333
# Epoch 63/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5671 - loss: 1.1345 - val_accuracy: 0.5991 - val_loss: 1.0619
# Epoch 64/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.7188 - loss: 0.9307 - val_accuracy: 0.5000 - val_loss: 1.0096
# Epoch 65/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5724 - loss: 1.1244 - val_accuracy: 0.6053 - val_loss: 1.0492
# Epoch 66/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.6250 - loss: 1.0124 - val_accuracy: 0.6000 - val_loss: 1.2478
# Epoch 67/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5738 - loss: 1.1235 - val_accuracy: 0.6028 - val_loss: 1.0515
# Epoch 68/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.5312 - loss: 1.1665 - val_accuracy: 0.3000 - val_loss: 1.4642
# Epoch 69/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5739 - loss: 1.1176 - val_accuracy: 0.5984 - val_loss: 1.0575
# Epoch 70/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.5000 - loss: 1.2685 - val_accuracy: 0.6000 - val_loss: 1.1642
# Epoch 71/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5740 - loss: 1.1278 - val_accuracy: 0.6011 - val_loss: 1.0620
# Epoch 72/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6250 - loss: 1.0274 - val_accuracy: 0.5000 - val_loss: 1.2449
# Epoch 73/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5796 - loss: 1.1122 - val_accuracy: 0.6083 - val_loss: 1.0490
# Epoch 74/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.6562 - loss: 1.0103 - val_accuracy: 0.5000 - val_loss: 1.0588
# Epoch 75/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5732 - loss: 1.1240 - val_accuracy: 0.6016 - val_loss: 1.0458
# Epoch 76/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.4688 - loss: 1.1189 - val_accuracy: 0.7000 - val_loss: 0.7484
# Epoch 77/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - accuracy: 0.5796 - loss: 1.1067 - val_accuracy: 0.6087 - val_loss: 1.0469
# Epoch 78/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.6562 - loss: 1.1044 - val_accuracy: 1.0000 - val_loss: 0.4769
# Epoch 79/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5789 - loss: 1.1088 - val_accuracy: 0.5972 - val_loss: 1.0621
# Epoch 80/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.6562 - loss: 1.0805 - val_accuracy: 0.5000 - val_loss: 1.2684
# Epoch 81/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 65s 72ms/step - accuracy: 0.5834 - loss: 1.0986 - val_accuracy: 0.5940 - val_loss: 1.0632
# Epoch 82/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.5312 - loss: 1.2227 - val_accuracy: 0.6000 - val_loss: 0.9941
# Epoch 83/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - accuracy: 0.5829 - loss: 1.0945 - val_accuracy: 0.6039 - val_loss: 1.0615
# Epoch 84/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.4375 - loss: 1.1190 - val_accuracy: 0.5000 - val_loss: 1.6576
# Epoch 85/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 68s 75ms/step - accuracy: 0.5868 - loss: 1.0952 - val_accuracy: 0.6130 - val_loss: 1.0371
# Epoch 86/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.7500 - loss: 0.7803 - val_accuracy: 0.3000 - val_loss: 1.7231
# Epoch 87/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5858 - loss: 1.0867 - val_accuracy: 0.6145 - val_loss: 1.0334
# Epoch 88/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 16us/step - accuracy: 0.5312 - loss: 1.2257 - val_accuracy: 0.7000 - val_loss: 1.2533
# Epoch 89/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 70s 77ms/step - accuracy: 0.5840 - loss: 1.0905 - val_accuracy: 0.6140 - val_loss: 1.0384
# Epoch 90/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.7812 - loss: 0.9523 - val_accuracy: 0.7000 - val_loss: 0.5242
# Epoch 91/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 66s 73ms/step - accuracy: 0.5891 - loss: 1.0856 - val_accuracy: 0.6077 - val_loss: 1.0537
# Epoch 92/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.7500 - loss: 0.7761 - val_accuracy: 0.7000 - val_loss: 0.9814
# Epoch 93/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 67s 74ms/step - accuracy: 0.5896 - loss: 1.0800 - val_accuracy: 0.6028 - val_loss: 1.0545
# Epoch 94/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 15us/step - accuracy: 0.5625 - loss: 1.1978 - val_accuracy: 0.5000 - val_loss: 1.1726
# Epoch 95/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 63s 70ms/step - accuracy: 0.5846 - loss: 1.0885 - val_accuracy: 0.6095 - val_loss: 1.0451
# Epoch 96/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 14us/step - accuracy: 0.4062 - loss: 1.3562 - val_accuracy: 0.6000 - val_loss: 1.5539
# Epoch 97/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 64s 70ms/step - accuracy: 0.5870 - loss: 1.0831 - val_accuracy: 0.6162 - val_loss: 1.0242
# Epoch 98/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.6562 - loss: 0.8380 - val_accuracy: 0.5000 - val_loss: 1.2021
# Epoch 99/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 64s 71ms/step - accuracy: 0.5886 - loss: 1.0883 - val_accuracy: 0.6158 - val_loss: 1.0400
# Epoch 100/100
# 897/897 ━━━━━━━━━━━━━━━━━━━━ 0s 13us/step - accuracy: 0.5312 - loss: 1.0770 - val_accuracy: 0.7000 - val_loss: 1.0426

# %%
model.save('emotion_detection_model_100epochs.h5')

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = history.history['accuracy']
#acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
#val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model

# %%
#Test the model
my_model = load_model('emotion_detection_model_100epochs.h5', compile=False)

# %%
#Generate a batch of images
test_img, test_lbl = validation_generator.__next__()
predictions=my_model.predict(test_img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step

# %%
predictions = np.argmax(predictions, axis=1)
test_labels = np.argmax(test_lbl, axis=1)

# %%
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predictions))
# Out:
# Accuracy =  0.75

# %%
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(test_labels, predictions)
import seaborn as sns
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
class_labels=['Angry','Disgust', 'Fear', 'Happy','Neutral','Sad','Surprise']
#Check results on a few select images
n=random.randint(0, test_img.shape[0] - 1)
image = test_img[n]
orig_labl = class_labels[test_labels[n]]
pred_labl = class_labels[predictions[n]]
plt.imshow(image[:,:,0], cmap='gray')
plt.title("Original label is:"+orig_labl+" Predicted is: "+ pred_labl)
plt.show()
